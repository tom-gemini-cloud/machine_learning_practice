# %% [markdown]
# # Getting Started with Scikit-learn for ML

# %% [markdown]
# ## Using the Scikit-learn Dataset

# %%
from sklearn import datasets
iris = datasets.load_iris()
print(iris.data)
print(iris.DESCR)
